# %%
# !cd ..
# Out:
# /content

# %%
! rm -r NLA_project_2025
# Out:
# rm: cannot remove 'NLA_project_2025': No such file or directory

# %%
# !git clone -b msign --single-branch https://github.com/iillyya/NLA_project_2025.git
# Out:
# Cloning into 'NLA_project_2025'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 84 (delta 45), reused 77 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 228.75 KiB | 9.95 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
cd NLA_project_2025/src
# Out:
# /content/NLA_project_2025/src

# %%
ls results
# Out:
# update-adam-lr-0.1-wd-0.0-seed-0.pkl
# update-hyperspherical_descent-lr-0.1-wd-0.0-seed-0.pkl
# update-manifold_muon-msign-ns5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl
# update-manifold_muon-msign-polarexpress-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 10 --lr 0.1 --update adam --wd 0.0
# Out:
# Training with: adam
# Epochs: 10 --- LR: 0.1 --- WD: 0.0
# device: cuda
# Epoch 1, Loss: 33.866047382354736, Time: 11.2989 seconds
# Epoch 2, Loss: 2.3031531888611463, Time: 11.1650 seconds
# Epoch 3, Loss: 2.302597187003311, Time: 11.2753 seconds
# Epoch 4, Loss: 2.3025487053151035, Time: 11.1612 seconds
# Epoch 5, Loss: 2.3025457469784483, Time: 10.6040 seconds
# Epoch 6, Loss: 2.302544267810121, Time: 11.0243 seconds
# Epoch 7, Loss: 2.302543440643622, Time: 11.2571 seconds
# Epoch 8, Loss: 2.302542983269205, Time: 11.2014 seconds
# Epoch 9, Loss: 2.3025426232084936, Time: 11.3067 seconds
# Epoch 10, Loss: 2.302542428581082, Time: 11.0837 seconds
# Accuracy of the network on the 10000 test images: 10.0 %
# Accuracy of the network on the 50000 train images: 10.002 %
# Saving results to results/update-adam-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-adam-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update hyperspherical_descent
# Out:
# Training with: hyperspherical_descent
# Epochs: 5 --- LR: 0.1
# device: cuda
# Epoch 1, Loss: 2.0660259358736934, Time: 10.8429 seconds
# Epoch 2, Loss: 1.970173482992211, Time: 14.1116 seconds
# Epoch 3, Loss: 1.9593441535015494, Time: 12.0657 seconds
# Epoch 4, Loss: 1.9534515604680898, Time: 10.8312 seconds
# Epoch 5, Loss: 1.9500470502035958, Time: 10.9246 seconds
# Accuracy of the network on the 10000 test images: 27.74 %
# Accuracy of the network on the 50000 train images: 28.0 %
# Saving results to results/update-hyperspherical_descent-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-hyperspherical_descent-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update manifold_muon --msign polarexpress --msign_steps 5
# Out:
# Training with: manifold_muon
# Epochs: 5 --- LR: 0.1
# msign: polarexpress --- msign_steps: 5
# device: cuda
# Epoch 1, Loss: 1.7082458272272227, Time: 33.6600 seconds
# Epoch 2, Loss: 1.4393119447085323, Time: 33.0497 seconds
# Epoch 3, Loss: 1.302863427570888, Time: 32.5835 seconds
# Epoch 4, Loss: 1.2072632069490394, Time: 32.6864 seconds
# Epoch 5, Loss: 1.1336244490681862, Time: 32.6819 seconds
# Accuracy of the network on the 10000 test images: 52.2 %
# Accuracy of the network on the 50000 train images: 64.446 %
# Saving results to results/update-manifold_muon-msign-polarexpress-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-manifold_muon-msign-polarexpress-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update manifold_muon --msign ns5 --msign_steps 5
# Out:
# Training with: manifold_muon
# Epochs: 5 --- LR: 0.1
# msign: ns5 --- msign_steps: 5
# device: cuda
# Epoch 1, Loss: 1.7080127609019378, Time: 35.5087 seconds
# Epoch 2, Loss: 1.452416865193114, Time: 35.0300 seconds
# Epoch 3, Loss: 1.3263033312194201, Time: 35.0706 seconds
# Epoch 4, Loss: 1.241081495674289, Time: 35.6982 seconds
# Epoch 5, Loss: 1.181867548397609, Time: 36.4117 seconds
# Accuracy of the network on the 10000 test images: 52.75 %
# Accuracy of the network on the 50000 train images: 62.346 %
# Saving results to results/update-manifold_muon-msign-ns5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-manifold_muon-msign-ns5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update manifold_muon --msign jordan5  --msign_steps 5
# Out:
# Training with: manifold_muon
# Epochs: 5 --- LR: 0.1
# msign: jordan5 --- msign_steps: 5
# device: cuda
# Epoch 1, Loss: 1.7389143267456366, Time: 36.0163 seconds
# Epoch 2, Loss: 1.5100928934252993, Time: 35.5963 seconds
# Epoch 3, Loss: 1.4025726877913183, Time: 35.0927 seconds
# Epoch 4, Loss: 1.332916150287706, Time: 35.2673 seconds
# Epoch 5, Loss: 1.2910554992909333, Time: 35.5953 seconds
# Accuracy of the network on the 10000 test images: 50.02 %
# Accuracy of the network on the 50000 train images: 57.644 %
# Saving results to results/update-manifold_muon-msign-jordan5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-manifold_muon-msign-jordan5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update manifold_muon --msign svd_ref --msign_steps 1
# Out:
# Training with: manifold_muon
# Epochs: 5 --- LR: 0.1
# msign: svd_ref --- msign_steps: 1
# device: cuda
# Epoch 1, Loss: 1.6975350769198672, Time: 53.7181 seconds
# Epoch 2, Loss: 1.4169328139752757, Time: 53.0308 seconds
# Epoch 3, Loss: 1.2778583400103511, Time: 52.1926 seconds
# Epoch 4, Loss: 1.1786643801903238, Time: 52.2311 seconds
# Epoch 5, Loss: 1.1057937972399654, Time: 52.3998 seconds
# Accuracy of the network on the 10000 test images: 53.23 %
# Accuracy of the network on the 50000 train images: 66.546 %
# Saving results to results/update-manifold_muon-msign-svd_ref-msignsteps-1-lr-0.1-wd-0.0-seed-0.pkl
# Results saved to results/update-manifold_muon-msign-svd_ref-msignsteps-1-lr-0.1-wd-0.0-seed-0.pkl

# %%
# !python main_2.py --device cuda --seed 0 --epochs 5 --lr 0.1 --update manifold_muon --msign you6    --msign_steps 6
# Out:
# usage: main_2.py [-h] [--epochs EPOCHS] [--lr LR]
#                  [--update {manifold_muon,hyperspherical_descent,adam}]
#                  [--seed SEED] [--wd WD] [--device {cpu,cuda}]
#                  [--msign {polarexpress,ns5,jordan5,svd_ref}]
#                  [--msign_steps MSIGN_STEPS]
# main_2.py: error: argument --msign: invalid choice: 'you6' (choose from polarexpress, ns5, jordan5, svd_ref)

# %%
RESULTS_DIR = "results"
LR = "0.1"
WD = "0.0"
SEEDS = [0]

MUON_VARIANTS = [
    ("polarexpress", 5),
    ("ns5", 5),
    ("jordan5", 5),
    ("svd_ref", 1),
    ("you6", 6),
]

SAVE_DIR = "figures"
SAVE_PREFIX = f"cifar10_lr{LR}_wd{WD}_seeds{'-'.join(map(str,SEEDS))}"

import os, io, pickle
from typing import Any, Dict, List, Tuple
import numpy as np
import torch
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams["text.usetex"] = False
mpl.rcParams.update({
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.linewidth": 0.8,
})

Results = Dict[str, Any]

def torch_load_cpu(path: str):
    return torch.load(path, map_location="cpu", weights_only=False)

def pickle_load(path: str):
    with open(path, "rb") as f:
        return pickle.load(f)

def load_results(path: str) -> Results:
    try:
        obj = torch_load_cpu(path)
    except Exception:
        try:
            with open(path, "rb") as f:
                buf = io.BytesIO(f.read())
            obj = torch.load(buf, map_location="cpu", weights_only=False)
        except Exception:
            obj = pickle_load(path)
    if not isinstance(obj, dict):
        raise TypeError(f"{path} does not contain a dict.")
    return obj

def to_cpu_tensor(x) -> torch.Tensor:
    if isinstance(x, torch.Tensor):
        return x.detach().cpu()
    if isinstance(x, (list, tuple, np.ndarray)):
        return torch.tensor(x)
    return torch.tensor([x])

def mean_std_stack(arrs: List[np.ndarray]) -> Tuple[np.ndarray, np.ndarray]:
    A = np.stack(arrs, axis=0)
    return A.mean(axis=0), A.std(axis=0, ddof=0)

def spectral_norms_from_singular_values(svals_list) -> np.ndarray:
    out = []
    for svals in svals_list:
        t = to_cpu_tensor(svals).float().flatten()
        out.append(float(t.max().item()) if t.numel() else np.nan)
    return np.array(out, dtype=float)

def fname_adam(seed: int) -> str:
    return f"update-adam-lr-{LR}-wd-{WD}-seed-{seed}.pkl"

def fname_hyp(seed: int) -> str:
    return f"update-hyperspherical_descent-lr-{LR}-wd-{WD}-seed-{seed}.pkl"

def fname_muon(msign: str, msteps: int, seed: int) -> str:
    return f"update-manifold_muon-msign-{msign}-msignsteps-{msteps}-lr-{LR}-wd-{WD}-seed-{seed}.pkl"

def label_muon(msign: str, msteps: int) -> str:
    return f"manifold_muon/{msign})"

expected: List[str] = []
expected.append("adam")
expected.append("hyperspherical_descent")
for msign, msteps in MUON_VARIANTS:
    expected.append(label_muon(msign, msteps))

runs: Dict[str, List[Results]] = {lab: [] for lab in expected}
missing = []

for seed in SEEDS:
    p = os.path.join(RESULTS_DIR, fname_adam(seed))
    if os.path.isfile(p):
        runs["adam"].append(load_results(p))
    else:
        missing.append(p)

    p = os.path.join(RESULTS_DIR, fname_hyp(seed))
    if os.path.isfile(p):
        runs["hyperspherical_descent"].append(load_results(p))
    else:
        missing.append(p)

    for msign, msteps in MUON_VARIANTS:
        lab = label_muon(msign, msteps)
        p = os.path.join(RESULTS_DIR, fname_muon(msign, msteps, seed))
        if os.path.isfile(p):
            runs[lab].append(load_results(p))
        else:
            missing.append(p)

present = {k: v for k, v in runs.items() if len(v) > 0}
if not present:
    raise SystemExit("No result files found for the given SETTINGS.")
if missing:
    print("Missing files (ignored):")
    for p in missing:
        print(" ", p)

agg = {}
for lab, lst in present.items():
    epochs_declared = int(lst[0].get("epochs", 0))
    losses = [np.array(r["epoch_losses"], dtype=float) for r in lst]
    times  = [np.array(r["epoch_times"], dtype=float)  for r in lst]

    if len(losses) > 1:
        loss_m, loss_s = mean_std_stack(losses)
        time_m, time_s = mean_std_stack(times)
    else:
        loss_m, loss_s = losses[0], np.zeros_like(losses[0])
        time_m, time_s = times[0],  np.zeros_like(times[0])

    test_accs  = np.array([float(r["test_acc"])  for r in lst], dtype=float)
    train_accs = np.array([float(r["train_acc"]) for r in lst], dtype=float)

    norms_per_seed = []
    for r in lst:
        norms = []
        for n in r["norms"]:
            t = to_cpu_tensor(n).float().flatten()
            norms.append(float(t.item()) if t.numel() == 1 else float(t.mean().item()))
        norms_per_seed.append(np.array(norms, dtype=float))
    norms_per_seed = np.stack(norms_per_seed, axis=0)
    norms_m = norms_per_seed.mean(axis=0)
    norms_s = norms_per_seed.std(axis=0, ddof=0)

    spec_per_seed = []
    for r in lst:
        spec_per_seed.append(spectral_norms_from_singular_values(r["singular_values"]))
    spec_per_seed = np.stack(spec_per_seed, axis=0)
    spec_m = np.nanmean(spec_per_seed, axis=0)
    spec_s = np.nanstd(spec_per_seed, axis=0, ddof=0)

    agg[lab] = {
        "epochs_declared": epochs_declared,
        "loss_m": loss_m, "loss_s": loss_s,
        "time_m": time_m, "time_s": time_s,
        "test_m": float(test_accs.mean()),  "test_s": float(test_accs.std(ddof=0)),
        "train_m": float(train_accs.mean()), "train_s": float(train_accs.std(ddof=0)),
        "norms_m": norms_m, "norms_s": norms_s,
        "spec_m": spec_m, "spec_s": spec_s,
    }

labels = list(agg.keys())
n_layers = len(next(iter(agg.values()))["norms_m"])
layer_idx = np.arange(n_layers)
layer_labels = [f"W{i+1}" for i in range(n_layers)]

os.makedirs(SAVE_DIR, exist_ok=True)

plt.figure(figsize=(7.2, 4.2))
for lab in labels:
    m = agg[lab]["loss_m"]; s = agg[lab]["loss_s"]
    x_epochs = np.arange(1, len(m) + 1)
    plt.plot(x_epochs, m, label=lab)
    plt.fill_between(x_epochs, m - s, m + s, alpha=0.2)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"Loss vs Epoch")
plt.legend(loc="best")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_loss.png"), bbox_inches="tight")
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_loss.pdf"), bbox_inches="tight")
plt.show()

plt.figure(figsize=(8.0, 4.2))
x = np.arange(len(labels))
width = 0.38
test_means  = [agg[lab]["test_m"]  for lab in labels]
test_stds   = [agg[lab]["test_s"]  for lab in labels]
train_means = [agg[lab]["train_m"] for lab in labels]
train_stds  = [agg[lab]["train_s"] for lab in labels]
plt.bar(x - width/2, test_means,  width, yerr=test_stds,  capsize=3, label="Test")
plt.bar(x + width/2, train_means, width, yerr=train_stds, capsize=3, label="Train")
plt.xticks(x, labels, rotation=18, ha="right")
plt.ylabel("Accuracy (%)")
plt.title(f"Final Accuracy  ")
plt.legend(loc="best")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_acc.png"), bbox_inches="tight")
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_acc.pdf"), bbox_inches="tight")
plt.show()

plt.figure(figsize=(8.0, 4.0))
avg_time_means = [float(np.mean(agg[lab]["time_m"])) for lab in labels]
avg_time_stds  = [float(np.mean(agg[lab]["time_s"])) for lab in labels]
plt.bar(x, avg_time_means, yerr=avg_time_stds, capsize=3)
plt.xticks(x, labels, rotation=18, ha="right")
plt.ylabel("sec/epoch")
plt.title(f"Average Epoch Time ")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_time.png"), bbox_inches="tight")
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_time.pdf"), bbox_inches="tight")
plt.show()

plt.figure(figsize=(8.6, 4.2))
group_width = 0.8
bar_w = group_width / max(1, len(labels))
for i, lab in enumerate(labels):
    offs = layer_idx - group_width/2 + bar_w*(i + 0.5)
    plt.bar(offs, agg[lab]["norms_m"], width=bar_w, yerr=agg[lab]["norms_s"], capsize=2, label=lab)
plt.xticks(layer_idx, layer_labels)
plt.ylabel("||W||_F")
plt.title(f"Frobenius Norms per Layer ")
plt.legend(loc="best")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_fro.png"), bbox_inches="tight")
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_fro.pdf"), bbox_inches="tight")
plt.show()

plt.figure(figsize=(8.6, 4.2))
for lab in labels:
    plt.errorbar(layer_idx, agg[lab]["spec_m"], yerr=agg[lab]["spec_s"], marker="o", capsize=2, label=lab)
plt.xticks(layer_idx, layer_labels)
plt.ylabel("||W||_2 (max σ)")
plt.title(f"Spectral Norms per Layer ")
plt.legend(loc="best")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_spec.png"), bbox_inches="tight")
plt.savefig(os.path.join(SAVE_DIR, f"{SAVE_PREFIX}_spec.pdf"), bbox_inches="tight")
plt.show()
# Out:
# /Users/a.konkin/anaconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 50, in load_results(path)
#      49 try:
# ---> 50     obj = torch_load_cpu(path)
#      51 except Exception:
#
# Cell In[1], line 42, in torch_load_cpu(path)
#      41 def torch_load_cpu(path: str):
# ---> 42     return torch.load(path, map_location="cpu", weights_only=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1802, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1800         f.seek(0)
# -> 1802 magic_number = pickle_module.load(f, **pickle_load_args)
#    1803 if magic_number != MAGIC_NUMBER:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/storage.py:534, in _load_from_bytes(b)
#     533 def _load_from_bytes(b):
# --> 534     return torch.load(io.BytesIO(b), weights_only=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1812, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1811 unpickler.persistent_load = persistent_load
# -> 1812 result = unpickler.load()
#    1814 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1747, in _legacy_load.<locals>.persistent_load(saved_id)
#    1746     obj._torch_load_uninitialized = True
# -> 1747     obj = restore_location(obj, location)
#    1748 # TODO: Once we decide to break serialization FC, we can
#    1749 # stop wrapping with TypedStorage
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:698, in default_restore_location(storage, location)
#     697 for _, _, fn in _package_registry:
# --> 698     result = fn(storage, location)
#     699     if result is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:636, in _deserialize(backend_name, obj, location)
#     635 if location.startswith(backend_name):
# --> 636     device = _validate_device(location, backend_name)
#     637     return obj.to(device=device)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:605, in _validate_device(location, backend_name)
#     604 if hasattr(device_module, "is_available") and not device_module.is_available():
# --> 605     raise RuntimeError(
#     606         f"Attempting to deserialize object on a {backend_name.upper()} "
#     607         f"device but torch.{backend_name}.is_available() is False. "
#     608         "If you are running on a CPU-only machine, "
#     609         "please use torch.load with map_location=torch.device('cpu') "
#     610         "to map your storages to the CPU."
#     611     )
#     612 if hasattr(device_module, "device_count"):
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 55, in load_results(path)
#      54         buf = io.BytesIO(f.read())
# ---> 55     obj = torch.load(buf, map_location="cpu", weights_only=False)
#      56 except Exception:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1802, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1800         f.seek(0)
# -> 1802 magic_number = pickle_module.load(f, **pickle_load_args)
#    1803 if magic_number != MAGIC_NUMBER:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/storage.py:534, in _load_from_bytes(b)
#     533 def _load_from_bytes(b):
# --> 534     return torch.load(io.BytesIO(b), weights_only=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1812, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1811 unpickler.persistent_load = persistent_load
# -> 1812 result = unpickler.load()
#    1814 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1747, in _legacy_load.<locals>.persistent_load(saved_id)
#    1746     obj._torch_load_uninitialized = True
# -> 1747     obj = restore_location(obj, location)
#    1748 # TODO: Once we decide to break serialization FC, we can
#    1749 # stop wrapping with TypedStorage
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:698, in default_restore_location(storage, location)
#     697 for _, _, fn in _package_registry:
# --> 698     result = fn(storage, location)
#     699     if result is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:636, in _deserialize(backend_name, obj, location)
#     635 if location.startswith(backend_name):
# --> 636     device = _validate_device(location, backend_name)
#     637     return obj.to(device=device)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:605, in _validate_device(location, backend_name)
#     604 if hasattr(device_module, "is_available") and not device_module.is_available():
# --> 605     raise RuntimeError(
#     606         f"Attempting to deserialize object on a {backend_name.upper()} "
#     607         f"device but torch.{backend_name}.is_available() is False. "
#     608         "If you are running on a CPU-only machine, "
#     609         "please use torch.load with map_location=torch.device('cpu') "
#     610         "to map your storages to the CPU."
#     611     )
#     612 if hasattr(device_module, "device_count"):
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 104
#     102 p = os.path.join(RESULTS_DIR, fname_adam(seed))
#     103 if os.path.isfile(p):
# --> 104     runs["adam"].append(load_results(p))
#     105 else:
#     106     missing.append(p)
#
# Cell In[1], line 57, in load_results(path)
#      55         obj = torch.load(buf, map_location="cpu", weights_only=False)
#      56     except Exception:
# ---> 57         obj = pickle_load(path)
#      58 if not isinstance(obj, dict):
#      59     raise TypeError(f"{path} does not contain a dict.")
#
# Cell In[1], line 46, in pickle_load(path)
#      44 def pickle_load(path: str):
#      45     with open(path, "rb") as f:
# ---> 46         return pickle.load(f)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/storage.py:534, in _load_from_bytes(b)
#     533 def _load_from_bytes(b):
# --> 534     return torch.load(io.BytesIO(b), weights_only=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1552     except pickle.UnpicklingError as e:
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1812, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1810 unpickler = UnpicklerWrapper(f, **pickle_load_args)
#    1811 unpickler.persistent_load = persistent_load
# -> 1812 result = unpickler.load()
#    1814 deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#    1816 if torch._guards.active_fake_mode() is None and not _serialization_tls.skip_data:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:1747, in _legacy_load.<locals>.persistent_load(saved_id)
#    1745     obj = cast(Storage, torch.UntypedStorage(nbytes))
#    1746     obj._torch_load_uninitialized = True
# -> 1747     obj = restore_location(obj, location)
#    1748 # TODO: Once we decide to break serialization FC, we can
#    1749 # stop wrapping with TypedStorage
#    1750 typed_storage = torch.storage.TypedStorage(
#    1751     wrap_storage=obj, dtype=dtype, _internal=True
#    1752 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:698, in default_restore_location(storage, location)
#     678 """
#     679 Restores `storage` using a deserializer function registered for the `location`.
#     680
#    (...)
#     695        all matching ones return `None`.
#     696 """
#     697 for _, _, fn in _package_registry:
# --> 698     result = fn(storage, location)
#     699     if result is not None:
#     700         return result
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:636, in _deserialize(backend_name, obj, location)
#     634     backend_name = torch._C._get_privateuse1_backend_name()
#     635 if location.startswith(backend_name):
# --> 636     device = _validate_device(location, backend_name)
#     637     return obj.to(device=device)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/serialization.py:605, in _validate_device(location, backend_name)
#     603     device_index = device.index if device.index else 0
#     604 if hasattr(device_module, "is_available") and not device_module.is_available():
# --> 605     raise RuntimeError(
#     606         f"Attempting to deserialize object on a {backend_name.upper()} "
#     607         f"device but torch.{backend_name}.is_available() is False. "
#     608         "If you are running on a CPU-only machine, "
#     609         "please use torch.load with map_location=torch.device('cpu') "
#     610         "to map your storages to the CPU."
#     611     )
#     612 if hasattr(device_module, "device_count"):
#     613     device_count = device_module.device_count()
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
# !zip -r src.zip src -x "*/.git/*" "*/__pycache__/*" "*.pyc"
# Out:
#   adding: src/ (stored 0%)
#   adding: src/msign_svd_polar.py (deflated 24%)
#   adding: src/hyperspherical_descent.py (deflated 40%)
#   adding: src/msign_you.py (deflated 50%)
#   adding: src/msign_jordan.py (deflated 44%)
#   adding: src/main_2.py (deflated 70%)
#   adding: src/msign.py (deflated 48%)
#   adding: src/manifold_muon.py (deflated 54%)
#   adding: src/msign_ns5.py (deflated 45%)
#   adding: src/figures/ (stored 0%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_loss.pdf (deflated 31%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_time.png (deflated 17%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_fro.png (deflated 25%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_acc.pdf (deflated 31%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_acc.png (deflated 17%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_fro.pdf (deflated 32%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_loss.png (deflated 17%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_time.pdf (deflated 33%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_spec.png (deflated 15%)
#   adding: src/figures/cifar10_lr0.1_wd0.0_seeds0_spec.pdf (deflated 34%)
#   adding: src/Project_NLA.ipynb (deflated 33%)
#   adding: src/Results.ipynb (deflated 51%)
#   adding: src/train.py (deflated 68%)
#   adding: src/results/ (stored 0%)
#   adding: src/results/update-adam-lr-0.1-wd-0.0-seed-0.pkl (deflated 48%)
#   adding: src/results/update-hyperspherical_descent-lr-0.1-wd-0.0-seed-0.pkl (deflated 47%)
#   adding: src/results/update-manifold_muon-msign-ns5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl (deflated 54%)
#   adding: src/results/.ipynb_checkpoints/ (stored 0%)
#   adding: src/results/update-manifold_muon-msign-jordan5-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl (deflated 50%)
#   adding: src/results/update-manifold_muon-msign-polarexpress-msignsteps-5-lr-0.1-wd-0.0-seed-0.pkl (deflated 49%)
#   adding: src/results/update-manifold_muon-msign-svd_ref-msignsteps-1-lr-0.1-wd-0.0-seed-0.pkl (deflated 62%)
#   adding: src/data/ (stored 0%)
#   adding: src/data/cifar-10-batches-py/ (stored 0%)
#   adding: src/data/cifar-10-batches-py/data_batch_3 (deflated 8%)
#   adding: src/data/cifar-10-batches-py/data_batch_5 (deflated 8%)
#   adding: src/data/cifar-10-batches-py/readme.html (stored 0%)
#   adding: src/data/cifar-10-batches-py/data_batch_1 (deflated 9%)
#   adding: src/data/cifar-10-batches-py/data_batch_4 (deflated 8%)
#   adding: src/data/cifar-10-batches-py/test_batch (deflated 8%)
#   adding: src/data/cifar-10-batches-py/data_batch_2 (deflated 8%)
#   adding: src/data/cifar-10-batches-py/batches.meta (deflated 12%)
#   adding: src/data/cifar-10-python.tar.gz (deflated 0%)
#   adding: src/main.py (deflated 66%)
